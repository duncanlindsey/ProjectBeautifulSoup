# %% [markdown]
# # UCL MSc - Module Scrape
# ## Preamble
# Import modules

# %%
import CompSciScrape as cs

# %% [markdown]
# ## Scraping the Computer Science Module Directory

# %%
# Specify URL location of module directory
parentURL = 'http://www.cs.ucl.ac.uk/'
targetURL = 'http://www.cs.ucl.ac.uk/current_students/syllabus/pg/'

# Collect soup
modules_soup = cs.collectSoup(targetURL)

# Find all module tags and parse modules into a pandas dataframe
modules_directory = cs.parseModuleList(modules_soup, parentURL)
print(modules_directory)
# Out:
# [<a href="current_students/syllabus/compg0/compg001_financial_data_and_statistics/" title="COMPG001 - Financial Data and Statistics">COMPG001 - Financial Data and Statistics</a>, <a href="current_students/syllabus/compg0/compg004_market_risk_measures_and_portfolio_theory/" title="COMPG004 - Market Risk Measures and Portfolio Theory">COMPG004 - Market Risk Measures and Portfolio Theory</a>, <a href="current_students/syllabus/compg0/compg005_numerical_analysis_for_finance/" title="COMPG005 - Numerical Analysis for Finance">COMPG005 - Numerical Analysis for Finance</a>, <a href="current_students/syllabus/compg0/compg007_operational_risk_measurement_for_financial_institutions/" title="COMPG007 - Operational Risk Measurement for Financial Institutions">COMPG007 - Operational Risk Measurement for Financial Institutions</a>, <a href="current_students/syllabus/compg0/compg008_stochastic_processes_for_finance/" title="COMPG008 - Stochastic Processes for Finance">COMPG008 - Stochastic Processes for Finance</a>, <a href="current_students/syllabus/compg0/compg009_networks_and_systemic_risk/" title="COMPG009 - Networks and Systemic Risk">COMPG009 - Networks and Systemic Risk</a>, <a href="current_students/syllabus/compg0/compg011_data_analytics/" title="COMPG011 - Data Analytics">COMPG011 - Data Analytics</a>, <a href="current_students/syllabus/compg0/compg012_financial_engineering/" title="COMPG012 - Financial Engineering">COMPG012 - Financial Engineering</a>, <a href="current_students/syllabus/compg0/compg013_market_microstructure/" title="COMPG013 - Market Microstructure">COMPG013 - Market Microstructure</a>, <a href="current_students/syllabus/compg0/compg014_machine_learning_with_applications_in_finance/" title="COMPG014 - Machine Learning with Applications in Finance">COMPG014 - Machine Learning with Applications in Finance</a>, <a href="current_students/syllabus/compgc/compgc18_entrepreneurship_theory_and_practice/" title="COMPG099 - Entrepreneurship: Theory and Practice">COMPG099 - Entrepreneurship: Theory and Practice</a>, <a href="current_students/syllabus/compga/compga01_computer_security_1/" title="COMPGA01 - Computer Security 1">COMPGA01 - Computer Security 1</a>, <a href="current_students/syllabus/compga/compga02_computer_security_2/" title="COMPGA02 - Computer Security 2">COMPGA02 - Computer Security 2</a>, <a href="current_students/syllabus/compga/compga03_introduction_to_cryptography/" title="COMPGA03 - Introduction to Cryptography">COMPGA03 - Introduction to Cryptography</a>, <a href="current_students/syllabus/compga/compga10_people_and_security/" title="COMPGA10 - People and Security">COMPGA10 - People and Security</a>, <a href="current_students/syllabus/compga/compga11_research_in_information_security/" title="COMPGA11 - Research in Information Security">COMPGA11 - Research in Information Security</a>, <a href="current_students/syllabus/compga/compga12_applied_cryptography/" title="COMPGA12 - Applied Cryptography">COMPGA12 - Applied Cryptography</a>, <a href="current_students/syllabus/compga/compga14_information_security_management/" title="COMPGA14 - Information Security Management">COMPGA14 - Information Security Management</a>, <a href="current_students/syllabus/compga/compga16_malware/" title="COMPGA16 - Malware">COMPGA16 - Malware</a>, <a href="current_students/syllabus/compga/compga17_privacy_enhancing_technologies/" title="COMPGA17 - Privacy Enhancing Technologies">COMPGA17 - Privacy Enhancing Technologies</a>, <a href="current_students/syllabus/compga/compga18_cryptanalysis/" title="COMPGA18 - Cryptanalysis">COMPGA18 - Cryptanalysis</a>, <a href="current_students/syllabus/compga/compga19_philosophy_politics_and_economics_of_security_and_privacy/" title="COMPGA19 - Philosophy, Politics and Economics of Security and Privacy">COMPGA19 - Philosophy, Politics and Economics of Security and Privacy</a>, <a href="current_students/syllabus/compga/compga99_thesis/" title="COMPGA99 - Thesis">COMPGA99 - Thesis</a>, <a href=" ...
